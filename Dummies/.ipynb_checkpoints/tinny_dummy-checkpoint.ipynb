# %%
import torch
import torch.nn as nn
import torch.optim as optim

# reproducibility
torch.manual_seed(0)

# synthetic dataset
X = torch.randn(500, 5)          # 5-feature inputs
y = (X.sum(dim=1) > 0).long()    # binary labels (fake rule)

# simple model
model = nn.Sequential(
    nn.Linear(5, 10),
    nn.ReLU(),
    nn.Linear(10, 2)
)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# train
for epoch in range(200):
    optimizer.zero_grad()
    loss = criterion(model(X), y)
    loss.backward()
    optimizer.step()

# %%
# attacker wants to reconstruct an input that looks like class 1
target_class = torch.tensor([1])

# start from random noise
x_fake = torch.randn(1, 5, requires_grad=True)

attack_optimizer = optim.Adam([x_fake], lr=0.1)

for step in range(300):
    attack_optimizer.zero_grad()
    
    output = model(x_fake)
    loss = -output[0, target_class]  # maximize class confidence
    
    loss.backward()
    attack_optimizer.step()

# final reconstructed input
print("Reconstructed input:", x_fake.detach())
print("Model prediction:", torch.softmax(model(x_fake), dim=1))
# Out:
# Reconstructed input: tensor([[29.4476, 31.1460, 29.2949, 28.4703, 30.8170]])
# Model prediction: tensor([[0., 1.]], grad_fn=<SoftmaxBackward0>)

# %% [markdown]
# ### 1️⃣ Baseline (already done)
#
# > You already saw:
#
# > + attacker reaches ~99% confidence
#
# > + reconstructed input converges nicely
#
# >> + That’s the danger zone.

# %% [markdown]
# ### 2️⃣ Add Regularization (L2 + dropout)
# + Train a slightly safer model

# %%
import torch
import torch.nn as nn
import torch.optim as optim

torch.manual_seed(0)

X = torch.randn(500, 5)
y = (X.sum(dim=1) > 0).long()

model_reg = nn.Sequential(
    nn.Linear(5, 10),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(10, 2)
)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model_reg.parameters(), lr=0.01, weight_decay=1e-2)

for _ in range(200):
    optimizer.zero_grad()
    loss = criterion(model_reg(X), y)
    loss.backward()
    optimizer.step()

# %%
target_class = torch.tensor([1])
x_fake = torch.randn(1, 5, requires_grad=True)

attack_opt = optim.Adam([x_fake], lr=0.1)

for _ in range(300):
    attack_opt.zero_grad()
    output = model_reg(x_fake)
    loss = -output[0, target_class]
    loss.backward()
    attack_opt.step()

print("Reconstructed:", x_fake.detach())
print("Confidence:", torch.softmax(model_reg(x_fake), dim=1))
# Out:
# Reconstructed: tensor([[29.0457, 28.8492, 28.7195, 29.9522, 28.6066]])
# Confidence: tensor([[0., 1.]], grad_fn=<SoftmaxBackward0>)

# %%
model_dp = nn.Sequential(
    nn.Linear(5, 10),
    nn.ReLU(),
    nn.Linear(10, 2)
)

optimizer = optim.Adam(model_dp.parameters(), lr=0.01)
noise_scale = 0.3

for _ in range(200):
    optimizer.zero_grad()
    loss = criterion(model_dp(X), y)
    loss.backward()

    # add noise to gradients (DP-style)
    for p in model_dp.parameters():
        if p.grad is not None:
            p.grad += torch.randn_like(p.grad) * noise_scale

    optimizer.step()

# %%
x_fake = torch.randn(1, 5, requires_grad=True)
attack_opt = optim.Adam([x_fake], lr=0.1)

for _ in range(300):
    attack_opt.zero_grad()
    output = model_dp(x_fake)
    loss = -output[0, target_class]
    loss.backward()
    attack_opt.step()

print("Reconstructed:", x_fake.detach())
print("Confidence:", torch.softmax(model_dp(x_fake), dim=1))
# Out:
# Reconstructed: tensor([[29.3921, 27.6993, 30.8632,  9.0127, 31.0817]])
# Confidence: tensor([[8.4989e-39, 1.0000e+00]], grad_fn=<SoftmaxBackward0>)
